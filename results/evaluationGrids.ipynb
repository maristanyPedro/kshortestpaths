# %%
import pandas as pd

# %% [markdown]
# ### Read the file defining all instances considered on grid graphs. The file is needed to recognize unsolved instances later.

# %%
instancesHeader = ['GRAPH', 'SOURCE', 'TARGET', 'K']

instancesDf = pd.read_csv('grid_instances.csv', delimiter=' ', header=None, names=instancesHeader)
instancesDf
# Out:
#                      GRAPH  SOURCE  TARGET        K
# 0      Grid-Problem10.grid    9511    4531       10
# 1      Grid-Problem10.grid    7811     252       10
# 2      Grid-Problem10.grid    7947    1413       10
# 3      Grid-Problem10.grid    8415    5293       10
# 4      Grid-Problem10.grid    9592    7948       10
# ...                    ...     ...     ...      ...
# 17995   Grid-Problem9.grid    5017    3141  1000000
# 17996   Grid-Problem9.grid    2034    2397  1000000
# 17997   Grid-Problem9.grid    5385    7307  1000000
# 17998   Grid-Problem9.grid    1366    6911  1000000
# 17999   Grid-Problem9.grid    9209    1802  1000000
#
# [18000 rows x 4 columns]

# %% [markdown]
# ### For our new algorithm, give a name to the columns in the corresponding results file. Then, read the file.

# %%
newAlgoHeader = ['ALGO', 'GRAPH', 'SOURCE', 'TARGET', 'K', 'TIME', 'COST_MIN', 'COST_MAX', 'SOLUTIONS', 'BDA_QUERIES', 'FAILED_BDA', 'EXPANSIONS_PER_BDA', 'EXPANSIONS_PER_FAILED_BDA', 'POOL_SIZE']

newAlgoDf = pd.read_csv('finalGridResults_na.csv', delimiter=';', header=None, names=newAlgoHeader)

# %% [markdown]
# ### For the KM algorithm, give a name to the columns in the corresponding results file. Then, read the file.

# %%
kurzHeader = ['ALGO', 'OPTIMISTIC', 'DUMMY', 'PRUNING', 'NODES', 'ARCS', 'SOURCE' , 'TARGET', 'K', 'SOLUTIONS', 'COST_MIN', 'COST_MAX', 'SUM_OF_COSTS', 'SP_TREES', 'SP_TREES_EXPANSIONS', 'TIME']

kurzDf = pd.read_csv('finalGridResults_kurz.csv', delimiter=';', header=None, names=kurzHeader)
kurzDf
# Out:
#        ALGO  OPTIMISTIC  DUMMY           PRUNING  NODES   ARCS  SOURCE  \
# 0      kurz  optimistic    NaN  distance-pruning  10000  39600    9511
# 1      kurz  optimistic    NaN  distance-pruning  10000  39600    7811
# 2      kurz  optimistic    NaN  distance-pruning  10000  39600    7947
# 3      kurz  optimistic    NaN  distance-pruning  10000  39600    8415
# 4      kurz  optimistic    NaN  distance-pruning  10000  39600    9592
# ...     ...         ...    ...               ...    ...    ...     ...
# 17501  kurz  optimistic    NaN  distance-pruning  10000  39600     232
# 17502  kurz  optimistic    NaN  distance-pruning  10000  39600    5385
# 17503  kurz  optimistic    NaN  distance-pruning  10000  39600    3425
# 17504  kurz  optimistic    NaN  distance-pruning  10000  39600    3464
# 17505  kurz  optimistic    NaN  distance-pruning  10000  39600    5798
#
#        TARGET        K  SOLUTIONS  COST_MIN  COST_MAX  SUM_OF_COSTS  SP_TREES  \
# 0        4531       10         10       243       244          2438         1
# 1         252       10         10       369       369          3690         1
# 2        1413       10         10       308       309          3084         1
# 3        5293       10         10       349       350          3494         1
# 4        7948       10         10       215       216          2152         1
# ...       ...      ...        ...       ...       ...           ...       ...
# 17501     570  1000000    1000000       178       192     190736677    347617
# 17502    7307  1000000    1000000       338       348     347110771     90046
# 17503    6211  1000000    1000000       140       160     158006532    257298
# 17504    4332  1000000    1000000       151       170     168030787    263531
# 17505    5147  1000000    1000000       200       217     215265270    422192
#
#        SP_TREES_EXPANSIONS     TIME
# 0                     8191    0.004
# 1                     8796    0.004
# 2                     7017    0.004
# 3                     8628    0.004
# 4                     5928    0.003
# ...                    ...      ...
# 17501            614221686  208.988
# 17502             77519544  199.780
# 17503            451601188  657.431
# 17504            398980779  560.481
# 17505            497998532  654.479
#
# [17506 rows x 16 columns]

# %% [markdown]
# ### Merge the new algorithm's results and the KM algorithm's results with the instance file.¶
# This gives us a big results table containing NaNs whenever one or both algorithm's did not solve an instance. If an instance was not solved by any of the algorithms, we discard it.

# %%
mergedDf = pd.merge(instancesDf, newAlgoDf, on=['GRAPH', 'SOURCE', 'TARGET', 'K'], how='left')
mergedDf = pd.merge(mergedDf, kurzDf, on=['SOURCE', 'TARGET', 'K'], how='left', suffixes=("_na", "_kurz"))
mergedDf = mergedDf.loc[mergedDf['TIME_kurz'].notna() | mergedDf['TIME_na'].notna()]
mergedDf
# Out:
#                      GRAPH  SOURCE  TARGET        K  ALGO_na  TIME_na  \
# 0      Grid-Problem10.grid    9511    4531       10      NaN    0.003
# 1      Grid-Problem10.grid    7811     252       10      NaN    0.004
# 2      Grid-Problem10.grid    7947    1413       10      NaN    0.002
# 3      Grid-Problem10.grid    8415    5293       10      NaN    0.002
# 4      Grid-Problem10.grid    9592    7948       10      NaN    0.002
# ...                    ...     ...     ...      ...      ...      ...
# 17995   Grid-Problem9.grid    5017    3141  1000000      NaN   11.324
# 17996   Grid-Problem9.grid    2034    2397  1000000      NaN    6.521
# 17997   Grid-Problem9.grid    5385    7307  1000000      NaN    6.789
# 17998   Grid-Problem9.grid    1366    6911  1000000      NaN   13.104
# 17999   Grid-Problem9.grid    9209    1802  1000000      NaN   10.725
#
#        COST_MIN_na  COST_MAX_na  SOLUTIONS_na  BDA_QUERIES  ...  \
# 0              243          244            10           15  ...
# 1              369          369            10           11  ...
# 2              308          309            10           11  ...
# 3              349          350            10           11  ...
# 4              215          216            10           15  ...
# ...            ...          ...           ...          ...  ...
# 17995          139          160       1000000      1873879  ...
# 17996          253          268       1000000      1563531  ...
# 17997          338          348       1000000      1455747  ...
# 17998          352          358       1000000      1934537  ...
# 17999          296          307       1000000      1772811  ...
#
#                 PRUNING    NODES     ARCS  SOLUTIONS_kurz COST_MIN_kurz  \
# 0      distance-pruning  10000.0  39600.0            10.0         243.0
# 1      distance-pruning  10000.0  39600.0            10.0         369.0
# 2      distance-pruning  10000.0  39600.0            10.0         308.0
# 3      distance-pruning  10000.0  39600.0            10.0         349.0
# 4      distance-pruning  10000.0  39600.0            10.0         215.0
# ...                 ...      ...      ...             ...           ...
# 17995               NaN      NaN      NaN             NaN           NaN
# 17996  distance-pruning  10000.0  39600.0       1000000.0         253.0
# 17997  distance-pruning  10000.0  39600.0       1000000.0         338.0
# 17998  distance-pruning  10000.0  39600.0       1000000.0         352.0
# 17999               NaN      NaN      NaN             NaN           NaN
#
#       COST_MAX_kurz  SUM_OF_COSTS  SP_TREES  SP_TREES_EXPANSIONS  TIME_kurz
# 0             244.0        2438.0       1.0               8191.0      0.004
# 1             369.0        3690.0       1.0               8796.0      0.004
# 2             309.0        3084.0       1.0               7017.0      0.004
# 3             350.0        3494.0       1.0               8628.0      0.004
# 4             216.0        2152.0       1.0               5928.0      0.003
# ...             ...           ...       ...                  ...        ...
# 17995           NaN           NaN       NaN                  NaN        NaN
# 17996         268.0   266481448.0  248370.0          379481958.0    141.850
# 17997         348.0   347110771.0   90046.0           77519544.0    199.780
# 17998         358.0   357527320.0   25029.0           24292185.0     24.594
# 17999           NaN           NaN       NaN                  NaN        NaN
#
# [18000 rows x 27 columns]

# %% [markdown]
# ### Generate LaTeX table using geometric means and setting unsolved instances to the time limit T=7200s.

# %%
from scipy.stats import gmean
#mergedDf.loc[mergedDf['TIME_kurz'].isna(), 'TIME_kurz'] = 7200
#mergedDf.loc[mergedDf['TIME_na'].isna(), 'TIME_na'] = 7200
mergedDf['SPEEDUP'] = mergedDf['TIME_kurz']/mergedDf['TIME_na']
#testDf = mergedDf[mergedDf['TIME_kurz'] >= mergedDf['TIME_na']]
print("{} {} {} {} {}\n".format("GRAPH", "K", "SPEEDUP", "SOLVED-NA", "SOLVED-KURZ", "TIME_kurz"))
for graphName, graphDf in mergedDf.groupby(by='GRAPH'):
    for pathsCount, pathsCountDf in graphDf.groupby(by='K'):
        averageSpeedup = gmean(pathsCountDf[pathsCountDf['SPEEDUP'].notna()]['SPEEDUP'])
        dijkstraPolls = pathsCountDf[pathsCountDf['SPEEDUP'].notna()]['SP_TREES'].mean()
        #print(len(pathsCountDf[pathsCountDf['TIME_na'].notna()]))
        lenNa = len(pathsCountDf[pathsCountDf['SOLUTIONS_na'].notna()])
        lenKurz = len(pathsCountDf[pathsCountDf['SOLUTIONS_kurz'].notna()])
        timeKurz = pathsCountDf[pathsCountDf['TIME_kurz'].notna()]['TIME_kurz'].mean()
        print("{} {} {:.2f} {} {} {:.2f} {:.2f}\n".format(graphName.split('.')[-2], pathsCount, averageSpeedup, lenNa, lenKurz, dijkstraPolls, timeKurz))
# Out:
# GRAPH K SPEEDUP SOLVED-NA SOLVED-KURZ
#
# Grid-Problem1 10 0.00 200 200 1.78 0.00
#
# Grid-Problem1 100 2.25 200 200 17.27 0.01
#
# Grid-Problem1 1000 3.61 200 200 222.59 0.07
#
# Grid-Problem1 5000 4.26 200 200 1275.06 0.37
#
# Grid-Problem1 10000 4.59 200 200 2766.44 0.76
#
# Grid-Problem1 50000 8.21 200 200 15291.84 10.12
#
# Grid-Problem1 100000 7.04 200 200 31649.78 18.31
#
# Grid-Problem1 500000 7.60 200 193 158106.74 95.85
#
# Grid-Problem1 1000000 7.70 200 158 260863.54 147.27
#
# Grid-Problem10 10 0.00 200 200 1.53 0.00
#
# Grid-Problem10 100 1.93 200 200 14.14 0.01
#
# Grid-Problem10 1000 3.03 200 200 192.26 0.07
#
# Grid-Problem10 5000 3.88 200 200 1182.48 0.34
#
# Grid-Problem10 10000 4.59 200 200 2540.82 0.75
#
# Grid-Problem10 50000 8.96 200 200 13478.01 8.85
#
# Grid-Problem10 100000 8.56 200 200 29620.94 18.03
#
# Grid-Problem10 500000 8.88 200 196 153555.12 95.30
#
# Grid-Problem10 1000000 8.13 200 167 255848.26 121.98
#
# Grid-Problem2 10 0.00 200 200 1.77 0.00
#
# Grid-Problem2 100 2.60 200 200 21.15 0.01
#
# Grid-Problem2 1000 3.94 200 200 250.28 0.07
#
# Grid-Problem2 5000 5.03 200 200 1363.64 0.37
#
# Grid-Problem2 10000 5.62 200 200 2932.33 0.78
#
# Grid-Problem2 50000 10.69 200 200 16064.69 8.31
#
# Grid-Problem2 100000 11.62 200 200 32667.76 18.56
#
# Grid-Problem2 500000 11.99 200 198 171668.10 106.04
#
# Grid-Problem2 1000000 11.41 200 155 267269.38 157.07
#
# Grid-Problem3 10 0.00 200 200 1.56 0.00
#
# Grid-Problem3 100 2.32 200 200 15.94 0.01
#
# Grid-Problem3 1000 3.50 200 200 211.13 0.07
#
# Grid-Problem3 5000 4.32 200 200 1244.66 0.35
#
# Grid-Problem3 10000 4.86 200 200 2676.66 0.73
#
# Grid-Problem3 50000 8.71 200 200 14967.04 9.81
#
# Grid-Problem3 100000 7.89 200 200 29347.74 19.03
#
# Grid-Problem3 500000 7.76 200 194 156930.31 99.81
#
# Grid-Problem3 1000000 7.80 200 153 250459.92 162.03
#
# Grid-Problem4 10 0.00 200 200 1.74 0.00
#
# Grid-Problem4 100 2.34 200 200 14.51 0.01
#
# Grid-Problem4 1000 3.73 200 200 202.18 0.07
#
# Grid-Problem4 5000 4.52 200 200 1222.19 0.36
#
# Grid-Problem4 10000 4.85 200 200 2665.89 0.76
#
# Grid-Problem4 50000 9.50 200 200 14501.77 8.36
#
# Grid-Problem4 100000 10.48 200 200 31132.35 15.74
#
# Grid-Problem4 500000 8.79 200 194 159652.96 94.77
#
# Grid-Problem4 1000000 9.73 200 158 260709.30 132.50
#
# Grid-Problem5 10 0.00 200 200 1.68 0.00
#
# Grid-Problem5 100 2.47 200 200 19.50 0.01
#
# Grid-Problem5 1000 3.86 200 200 243.93 0.07
#
# Grid-Problem5 5000 4.96 200 200 1436.61 0.38
#
# Grid-Problem5 10000 5.37 200 200 2944.73 0.81
#
# Grid-Problem5 50000 9.73 200 200 16431.65 10.24
#
# Grid-Problem5 100000 10.83 200 200 34348.17 21.08
#
# Grid-Problem5 500000 9.61 200 194 171532.80 124.64
#
# Grid-Problem5 1000000 7.82 200 148 255105.97 139.59
#
# Grid-Problem6 10 0.00 200 200 1.55 0.00
#
# Grid-Problem6 100 2.30 200 200 16.27 0.01
#
# Grid-Problem6 1000 3.55 200 200 230.56 0.06
#
# Grid-Problem6 5000 4.42 200 200 1292.60 0.32
#
# Grid-Problem6 10000 5.08 200 200 2792.43 0.69
#
# Grid-Problem6 50000 9.79 200 200 15449.67 7.10
#
# Grid-Problem6 100000 10.67 200 200 33036.55 17.05
#
# Grid-Problem6 500000 10.82 200 195 168601.54 85.04
#
# Grid-Problem6 1000000 11.11 200 159 279958.83 137.64
#
# Grid-Problem7 10 0.00 200 200 1.69 0.00
#
# Grid-Problem7 100 2.41 200 200 18.21 0.01
#
# Grid-Problem7 1000 3.87 200 200 246.23 0.07
#
# Grid-Problem7 5000 4.94 200 200 1428.61 0.39
#
# Grid-Problem7 10000 5.37 200 200 3012.69 0.82
#
# Grid-Problem7 50000 11.06 200 200 16895.29 10.17
#
# Grid-Problem7 100000 9.66 200 200 33433.83 20.45
#
# Grid-Problem7 500000 11.47 200 196 175050.10 120.97
#
# Grid-Problem7 1000000 10.55 200 148 270974.84 165.76
#
# Grid-Problem8 10 0.00 200 200 1.51 0.00
#
# Grid-Problem8 100 2.39 200 200 16.40 0.01
#
# Grid-Problem8 1000 4.07 200 200 213.00 0.08
#
# Grid-Problem8 5000 5.38 200 200 1263.68 0.45
#
# Grid-Problem8 10000 5.91 200 200 2714.82 0.95
#
# Grid-Problem8 50000 10.65 200 200 14854.98 12.32
#
# Grid-Problem8 100000 9.75 200 200 31329.50 26.04
#
# Grid-Problem8 500000 12.07 200 194 160125.77 129.10
#
# Grid-Problem8 1000000 9.82 200 153 256325.59 146.12
#
# Grid-Problem9 10 0.00 200 200 1.32 0.00
#
# Grid-Problem9 100 2.21 200 200 14.51 0.01
#
# Grid-Problem9 1000 3.80 200 200 210.61 0.06
#
# Grid-Problem9 5000 5.13 200 200 1226.58 0.37
#
# Grid-Problem9 10000 5.69 200 200 2601.05 0.78
#
# Grid-Problem9 50000 10.75 200 200 14180.24 8.28
#
# Grid-Problem9 100000 11.73 200 200 30012.90 18.37
#
# Grid-Problem9 500000 9.97 200 197 157001.89 103.74
#
# Grid-Problem9 1000000 8.06 200 156 237585.36 137.82

# %%
mergedDf[mergedDf['GRAPH'].str.contains('CTR')]
# Out:
#                    GRAPH    SOURCE    TARGET        K  ALGO_na  TIME_na  \
# 5400  USA-road-dt.CTR.gr  12181763  10663437       10      NaN   7200.0
# 5401  USA-road-dt.CTR.gr  13263609   3512051       10      NaN   7200.0
# 5402  USA-road-dt.CTR.gr   8617129   2921811       10      NaN   7200.0
# 5403  USA-road-dt.CTR.gr  13145916    309892       10      NaN   7200.0
# 5404  USA-road-dt.CTR.gr  10923367   8213275       10      NaN   7200.0
# ...                  ...       ...       ...      ...      ...      ...
# 7195  USA-road-dt.CTR.gr    628005   7120819  1000000      NaN   7200.0
# 7196  USA-road-dt.CTR.gr   7228136  11312825  1000000      NaN   7200.0
# 7197  USA-road-dt.CTR.gr   4648576   7370601  1000000      NaN   7200.0
# 7198  USA-road-dt.CTR.gr   9644393  10542969  1000000      NaN   7200.0
# 7199  USA-road-dt.CTR.gr   3558135  10857567  1000000      NaN   7200.0
#
#       COST_MIN_na  COST_MAX_na  SOLUTIONS_na  BDA_QUERIES  ...       NODES  \
# 5400          NaN          NaN           NaN          NaN  ...  14081816.0
# 5401          NaN          NaN           NaN          NaN  ...  14081816.0
# 5402          NaN          NaN           NaN          NaN  ...  14081816.0
# 5403          NaN          NaN           NaN          NaN  ...  14081816.0
# 5404          NaN          NaN           NaN          NaN  ...  14081816.0
# ...           ...          ...           ...          ...  ...         ...
# 7195          NaN          NaN           NaN          NaN  ...         NaN
# 7196          NaN          NaN           NaN          NaN  ...         NaN
# 7197          NaN          NaN           NaN          NaN  ...         NaN
# 7198          NaN          NaN           NaN          NaN  ...         NaN
# 7199          NaN          NaN           NaN          NaN  ...         NaN
#
#             ARCS  SOLUTIONS_kurz  COST_MIN_kurz COST_MAX_kurz SUM_OF_COSTS  \
# 5400  34292496.0            10.0      1268594.0     1268594.0   12685940.0
# 5401  34292496.0            10.0      5474977.0     5474977.0   54749770.0
# 5402  34292496.0            10.0      8888964.0     8888964.0   88889640.0
# 5403  34292496.0            10.0     12879745.0    12879745.0  128797450.0
# 5404  34292496.0            10.0      3839849.0     3839849.0   38398490.0
# ...          ...             ...            ...           ...          ...
# 7195         NaN             NaN            NaN           NaN          NaN
# 7196         NaN             NaN            NaN           NaN          NaN
# 7197         NaN             NaN            NaN           NaN          NaN
# 7198         NaN             NaN            NaN           NaN          NaN
# 7199         NaN             NaN            NaN           NaN          NaN
#
#       SP_TREES SP_TREES_EXPANSIONS  TIME_kurz   SPEEDUP
# 5400       1.0            168979.0      1.627  0.000226
# 5401       1.0           3856891.0      3.875  0.000538
# 5402       1.0           7897146.0      7.238  0.001005
# 5403       1.0          10634038.0      8.625  0.001198
# 5404       1.0           1862878.0      1.920  0.000267
# ...        ...                 ...        ...       ...
# 7195       NaN                 NaN   7200.000  1.000000
# 7196       NaN                 NaN   7200.000  1.000000
# 7197       NaN                 NaN   7200.000  1.000000
# 7198       NaN                 NaN   7200.000  1.000000
# 7199       NaN                 NaN   7200.000  1.000000
#
# [1800 rows x 28 columns]
